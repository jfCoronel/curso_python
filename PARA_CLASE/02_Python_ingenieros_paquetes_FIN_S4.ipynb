# %% [markdown]
# ##Curso de Introducción a PYTHON para Ingenieros
# __La herramienta definitiva con ayuda de la IA.__
#
# _© Juan F. Coronel Toro, 2026_

# %% [markdown]
# # 2. Paquetes (Numpy, Matplotlib y Pandas)
# ## 2.1. Paquetes y Módulos en Python
#
# Python tiene una gran cantidad de bibliotecas disponibles, comúnmente citada como una de las mayores fortalezas de Python, que proporciona herramientas adecuadas para muchas tareas.
#
# El repositorio oficial de software de terceros para Python (Pypi) contiene más de 750.000 paquetes.
#
# Los módulos son archivos (`*.py`) que contienen código Python, como funciones, clases o variables. Mientras que los paquetes son carpetas que contienen un conjunto de módulos. Los paquetes son una forma de estructurar el espacio de nombres de los módulos, permitiendo una mejor organización y reutilización del código, especialmente en proyectos grandes.

# %% [markdown]
# ### 2.1.1. Paquetes incluidos en Python
#
# Python cuenta con algunos paquetes y módulos que ya vienen incluidos en el propio lenguaje (por ejemplo math)
#
# Para usar un módulo, tienes que *importarlo* usando el comando `import`.
#
# A partir de ese instante puedes utilizarlo en el código utilizando su nombre como prefijo.

# %%
# Ejemplo importación de módulo math
import math

x = math.cos(2 * math.pi)
x
# Out:
# 1.0

# %% [markdown]
# Para explorar la función y otros contenidos del módulo/biblioteca:
#
# - Utiliza la documentación web (por ejemplo, para la librería `math` <a href="https://docs.python.org/3/library/math.html">Doc para Python 3</a>)
# - Utiliza la función `help` incluida en python.

# %%
# Ejemplo de uso de la función help
help(math.sqrt)
# Out:
# Help on built-in function sqrt in module math:
#
# sqrt(x, /)
#     Return the square root of x.

# %% [markdown]
# podemos dar un alias al paquete/módulo usando `import xxxxx as xx`

# %%
# Ejemplo de alias de módulo
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# También podemos importar sólo algunas variables, funciones o clases concretas con `from paquete import constant1, function1`, después podemos usar directamente `constant1`, `function1` dentro del código.

# %%
# Ejemplo de importación funciones o variables de un módulo
from math import e,log

print(log(e**4))
# Out:
# 4.0

# %% [markdown]
# ### 2.1.2. Instalar paquetes
#
# Python también dispone de muchos paquetes que no vienen con el propio lenguaje, la biblioteca oficial de los paquetes de python puedes encontrarla en [pypi](https://pypi.org/)
#
# Para ver los paquetes que tenemos instalados podemos usar `pip list` en el terminal o `!pip list` en Google Colab
#
# El uso desde el terminal los veremos más adelante

# %%
# Ejecutar pip list desde Google Colab
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- -------------------
# absl-py                                  1.4.0
# accelerate                               1.13.0
# access                                   1.1.10.post3
# affine                                   2.4.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.13.3
# aiosignal                                1.4.0
# aiosqlite                                0.22.1
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.18.4
# altair                                   5.5.0
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# antlr4-python3-runtime                   4.9.3
# anyio                                    4.12.1
# anywidget                                0.9.21
# apsw                                     3.51.3.0
# apswutils                                0.1.2
# argon2-cffi                              25.1.0
# argon2-cffi-bindings                     25.1.0
# array_record                             0.8.3
# arrow                                    1.4.0
# arviz                                    0.22.0
# astropy                                  7.2.0
# astropy-iers-data                        0.2026.3.16.0.53.33
# astunparse                               1.6.3
# atpublic                                 5.1
# attrs                                    25.4.0
# audioread                                3.1.0
# Authlib                                  1.6.9
# autograd                                 1.8.0
# babel                                    2.18.0
# backcall                                 0.2.0
# beartype                                 0.22.9
# beautifulsoup4                           4.13.5
# betterproto                              2.0.0b6
# bigframes                                2.38.0
# bigquery-magics                          0.10.3
# bleach                                   6.3.0
# blinker                                  1.9.0
# blis                                     1.3.3
# blobfile                                 3.2.0
# blosc2                                   4.1.2
# bokeh                                    3.8.2
# Bottleneck                               1.4.2
# bqplot                                   0.12.45
# branca                                   0.8.2
# brotli                                   1.2.0
# CacheControl                             0.14.4
# cachetools                               6.2.6
# catalogue                                2.0.10
# certifi                                  2026.2.25
# cffi                                     2.0.0
# chardet                                  5.2.0
# charset-normalizer                       3.4.6
# clarabel                                 0.11.1
# click                                    8.3.1
# click-plugins                            1.1.1.2
# cligj                                    0.7.2
# cloudpathlib                             0.23.0
# cloudpickle                              3.1.2
# cmake                                    3.31.10
# cmdstanpy                                1.3.0
# colorcet                                 3.1.0
# colorlover                               0.3.0
# colour                                   0.1.5
# community                                1.0.0b1
# confection                               0.1.5
# cons                                     0.4.7
# contourpy                                1.3.3
# cowsay                                   6.1
# cramjam                                  2.11.0
# cryptography                             43.0.3
# cufflinks                                0.17.3
# curl_cffi                                0.14.0
# cvxopt                                   1.3.2
# cvxpy                                    1.6.7
# cycler                                   0.12.1
# cyipopt                                  1.5.0
# cymem                                    2.0.13
# Cython                                   3.0.12
# dask                                     2026.1.2
# dataproc-spark-connect                   1.0.2
# datasets                                 4.0.0
# db-dtypes                                1.5.0
# dbus-python                              1.2.18
# debugpy                                  1.8.15
# decorator                                4.4.2
# defusedxml                               0.7.1
# deprecation                              2.1.0
# diffusers                                0.37.0
# dill                                     0.3.8
# distro                                   1.9.0
# dlib                                     19.24.6
# dm-tree                                  0.1.9
# docstring_parser                         0.17.0
# docutils                                 0.21.2
# dopamine_rl                              4.1.2
# duckdb                                   1.3.2
# earthengine-api                          1.5.24
# easydict                                 1.13
# editdistance                             0.8.1
# eerepr                                   0.1.2
# einops                                   0.8.2
# en_core_web_sm                           3.8.0
# entrypoints                              0.4
# esda                                     2.8.2
# et_xmlfile                               2.0.0
# etils                                    1.14.0
# etuples                                  0.3.10
# Farama-Notifications                     0.0.4
# fastai                                   2.8.7
# fastapi                                  0.135.1
# fastcore                                 1.12.26
# fastdownload                             0.0.7
# fastjsonschema                           2.21.2
# fastlite                                 0.2.4
# fastprogress                             1.1.5
# fasttransform                            0.0.2
# ffmpy                                    1.0.0
# filelock                                 3.25.2
# fiona                                    1.10.1
# firebase-admin                           6.9.0
# Flask                                    3.1.3
# flatbuffers                              25.12.19
# flax                                     0.11.2
# folium                                   0.20.0
# fonttools                                4.62.1
# fqdn                                     1.5.1
# frozendict                               2.4.7
# frozenlist                               1.8.0
# fsspec                                   2025.3.0
# future                                   1.0.0
# gast                                     0.7.0
# gcsfs                                    2025.3.0
# GDAL                                     3.8.4
# gdown                                    5.2.1
# geemap                                   0.35.3
# geocoder                                 1.38.1
# geographiclib                            2.1
# geopandas                                1.1.3
# geopy                                    2.4.1
# giddy                                    2.3.8
# gin-config                               0.5.0
# gitdb                                    4.0.12
# GitPython                                3.1.46
# glob2                                    0.7
# google                                   3.0.0
# google-adk                               1.27.1
# google-ai-generativelanguage             0.6.15
# google-api-core                          2.30.0
# google-api-python-client                 2.192.0
# google-auth                              2.47.0
# google-auth-httplib2                     0.3.0
# google-auth-oauthlib                     1.3.0
# google-cloud-aiplatform                  1.141.0
# google-cloud-appengine-logging           1.8.0
# google-cloud-audit-log                   0.4.0
# google-cloud-bigquery                    3.40.1
# google-cloud-bigquery-connection         1.20.0
# google-cloud-bigquery-storage            2.36.2
# google-cloud-bigtable                    2.35.0
# google-cloud-core                        2.5.0
# google-cloud-dataplex                    2.16.0
# google-cloud-dataproc                    5.25.0
# google-cloud-datastore                   2.23.0
# google-cloud-discoveryengine             0.13.12
# google-cloud-firestore                   2.25.0
# google-cloud-functions                   1.22.0
# google-cloud-iam                         2.21.0
# google-cloud-language                    2.19.0
# google-cloud-logging                     3.14.0
# google-cloud-monitoring                  2.29.1
# google-cloud-pubsub                      2.36.0
# google-cloud-resource-manager            1.16.0
# google-cloud-secret-manager              2.26.0
# google-cloud-spanner                     3.63.0
# google-cloud-speech                      2.37.0
# google-cloud-storage                     3.9.0
# google-cloud-trace                       1.18.0
# google-cloud-translate                   3.24.0
# google-colab                             1.0.0
# google-crc32c                            1.8.0
# google-genai                             1.67.0
# google-generativeai                      0.8.6
# google-pasta                             0.2.0
# google-resumable-media                   2.8.0
# googleapis-common-protos                 1.73.0
# googledrivedownloader                    1.1.0
# gradio                                   5.50.0
# gradio_client                            1.14.0
# grain                                    0.2.16
# graphviz                                 0.21
# greenlet                                 3.3.2
# groovy                                   0.1.2
# grpc-google-iam-v1                       0.14.3
# grpc-interceptor                         0.15.4
# grpcio                                   1.78.0
# grpcio-status                            1.71.2
# grpclib                                  0.4.9
# gspread                                  6.2.1
# gspread-dataframe                        4.0.0
# gym                                      0.25.2
# gym-notices                              0.1.0
# gymnasium                                1.2.3
# h11                                      0.16.0
# h2                                       4.3.0
# h5netcdf                                 1.8.1
# h5py                                     3.16.0
# hdbscan                                  0.8.41
# hf-xet                                   1.4.2
# highspy                                  1.13.1
# holidays                                 0.93
# holoviews                                1.22.1
# hpack                                    4.1.0
# html5lib                                 1.1
# httpcore                                 1.0.9
# httpimport                               1.4.1
# httplib2                                 0.31.2
# httptools                                0.7.1
# httpx                                    0.28.1
# httpx-sse                                0.4.3
# huggingface_hub                          1.7.1
# humanize                                 4.15.0
# hyperframe                               6.1.0
# hyperopt                                 0.2.7
# ibis-framework                           9.5.0
# idna                                     3.11
# ImageIO                                  2.37.3
# imageio-ffmpeg                           0.6.0
# imagesize                                2.0.0
# imbalanced-learn                         0.14.1
# immutabledict                            4.3.1
# importlib_metadata                       8.7.1
# importlib_resources                      6.5.2
# imutils                                  0.5.4
# inequality                               1.1.2
# inflect                                  7.5.0
# iniconfig                                2.3.0
# intel-cmplr-lib-ur                       2025.3.2
# intel-openmp                             2025.3.2
# ipyevents                                2.0.4
# ipyfilechooser                           0.6.0
# ipykernel                                6.17.1
# ipyleaflet                               0.20.0
# ipyparallel                              8.8.0
# ipython                                  7.34.0
# ipython-genutils                         0.2.0
# ipython-sql                              0.5.0
# ipytree                                  0.2.2
# ipywidgets                               7.7.1
# isoduration                              20.11.0
# itsdangerous                             2.2.0
# jaraco.classes                           3.4.0
# jaraco.context                           6.1.1
# jaraco.functools                         4.4.0
# jax                                      0.7.2
# jaxlib                                   0.7.2
# jeepney                                  0.9.0
# jieba                                    0.42.1
# Jinja2                                   3.1.6
# jiter                                    0.13.0
# joblib                                   1.5.3
# jsonpatch                                1.33
# jsonpickle                               4.1.1
# jsonpointer                              3.0.0
# jsonschema                               4.26.0
# jsonschema-specifications                2025.9.1
# jupyter_client                           7.4.9
# jupyter-console                          6.6.3
# jupyter_core                             5.9.1
# jupyter-events                           0.12.0
# jupyter_kernel_gateway                   2.5.2
# jupyter-leaflet                          0.20.0
# jupyter_server                           2.14.0
# jupyter_server_terminals                 0.5.4
# jupyterlab_pygments                      0.3.0
# jupyterlab_widgets                       3.0.16
# jupytext                                 1.19.1
# kaggle                                   2.0.0
# kagglehub                                1.0.0
# kagglesdk                                0.1.16
# keras                                    3.13.2
# keras-hub                                0.26.0
# keras-nlp                                0.26.0
# keyring                                  25.7.0
# keyrings.google-artifactregistry-auth    1.1.2
# kiwisolver                               1.5.0
# langchain                                1.2.12
# langchain-core                           1.2.19
# langgraph                                1.1.2
# langgraph-checkpoint                     4.0.1
# langgraph-prebuilt                       1.0.8
# langgraph-sdk                            0.3.11
# langsmith                                0.7.18
# lark                                     1.3.1
# launchpadlib                             1.10.16
# lazr.restfulclient                       0.14.4
# lazr.uri                                 1.0.6
# lazy-loader                              0.5
# libclang                                 18.1.1
# libpysal                                 4.14.1
# librosa                                  0.11.0
# lightgbm                                 4.6.0
# linkify-it-py                            2.1.0
# llvmlite                                 0.43.0
# locket                                   1.0.0
# logical-unification                      0.4.7
# lxml                                     6.0.2
# Mako                                     1.3.10
# mapclassify                              2.10.0
# Markdown                                 3.10.2
# markdown-it-py                           4.0.0
# MarkupSafe                               3.0.3
# matplotlib                               3.10.0
# matplotlib-inline                        0.2.1
# matplotlib-venn                          1.1.2
# mcp                                      1.26.0
# mdit-py-plugins                          0.5.0
# mdurl                                    0.1.2
# mgwr                                     2.2.1
# miniKanren                               1.0.5
# missingno                                0.5.2
# mistune                                  3.2.0
# mizani                                   0.13.5
# mkl                                      2025.3.1
# ml_dtypes                                0.5.4
# mlxtend                                  0.23.4
# mmh3                                     5.2.1
# momepy                                   0.11.0
# more-itertools                           10.8.0
# moviepy                                  1.0.3
# mpmath                                   1.3.0
# msgpack                                  1.1.2
# multidict                                6.7.1
# multipledispatch                         1.0.0
# multiprocess                             0.70.16
# multitasking                             0.0.12
# murmurhash                               1.0.15
# music21                                  9.9.1
# namex                                    0.1.0
# narwhals                                 2.18.0
# natsort                                  8.4.0
# nbclassic                                1.3.3
# nbclient                                 0.10.4
# nbconvert                                7.17.0
# nbformat                                 5.10.4
# ndindex                                  1.10.1
# nest-asyncio                             1.6.0
# networkx                                 3.6.1
# nibabel                                  5.4.2
# nltk                                     3.9.1
# notebook                                 6.5.7
# notebook_shim                            0.2.4
# numba                                    0.60.0
# numexpr                                  2.14.1
# numpy                                    2.0.2
# nvidia-nccl-cu12                         2.29.7
# oauth2client                             4.1.3
# oauthlib                                 3.3.1
# omegaconf                                2.3.0
# onemkl-license                           2025.3.1
# openai                                   2.28.0
# opencv-contrib-python                    4.13.0.92
# opencv-python                            4.13.0.92
# opencv-python-headless                   4.13.0.92
# openpyxl                                 3.1.5
# opentelemetry-api                        1.38.0
# opentelemetry-exporter-gcp-logging       1.11.0a0
# opentelemetry-exporter-gcp-monitoring    1.11.0a0
# opentelemetry-exporter-gcp-trace         1.11.0
# opentelemetry-exporter-otlp-proto-common 1.38.0
# opentelemetry-exporter-otlp-proto-http   1.38.0
# opentelemetry-proto                      1.38.0
# opentelemetry-resourcedetector-gcp       1.11.0a0
# opentelemetry-sdk                        1.38.0
# opentelemetry-semantic-conventions       0.59b0
# opt_einsum                               3.4.0
# optax                                    0.2.7
# optree                                   0.19.0
# orbax-checkpoint                         0.11.33
# orjson                                   3.11.7
# ormsgpack                                1.12.2
# osqp                                     1.1.1
# overrides                                7.7.0
# packaging                                26.0
# pandas                                   2.2.2
# pandas-datareader                        0.10.0
# pandas-gbq                               0.30.0
# pandas-stubs                             2.2.2.240909
# pandocfilters                            1.5.1
# panel                                    1.8.10
# param                                    2.3.2
# parso                                    0.8.6
# parsy                                    2.2
# partd                                    1.4.2
# patsy                                    1.0.2
# peewee                                   4.0.2
# peft                                     0.18.1
# pexpect                                  4.9.0
# pickleshare                              0.7.5
# pillow                                   11.3.0
# pip                                      24.1.2
# platformdirs                             4.9.4
# plotly                                   5.24.1
# plotnine                                 0.14.5
# pluggy                                   1.6.0
# plum-dispatch                            2.7.1
# pointpats                                2.5.5
# polars                                   1.35.2
# polars-runtime-32                        1.35.2
# pooch                                    1.9.0
# portpicker                               1.5.2
# preshed                                  3.0.12
# prettytable                              3.17.0
# proglog                                  0.1.12
# progressbar2                             4.5.0
# prometheus_client                        0.24.1
# promise                                  2.3
# prompt_toolkit                           3.0.52
# propcache                                0.4.1
# prophet                                  1.3.0
# proto-plus                               1.27.1
# protobuf                                 5.29.6
# psutil                                   5.9.5
# psycopg2                                 2.9.11
# psygnal                                  0.15.1
# ptyprocess                               0.7.0
# PuLP                                     3.3.0
# py-cpuinfo                               9.0.0
# py4j                                     0.10.9.9
# pyarrow                                  18.1.0
# pyasn1                                   0.6.3
# pyasn1_modules                           0.4.2
# pycairo                                  1.29.0
# pycocotools                              2.0.11
# pycparser                                3.0
# pycryptodomex                            3.23.0
# pydantic                                 2.12.3
# pydantic_core                            2.41.4
# pydantic-settings                        2.13.1
# pydata-google-auth                       1.9.1
# pydot                                    4.0.1
# pydotplus                                2.0.2
# PyDrive2                                 1.21.3
# pydub                                    0.25.1
# pyerfa                                   2.0.1.5
# pygame                                   2.6.1
# pygit2                                   1.19.1
# Pygments                                 2.19.2
# PyGObject                                3.48.2
# pyiceberg                                0.11.1
# PyJWT                                    2.12.1
# pymc                                     5.28.1
# pynndescent                              0.6.0
# pyogrio                                  0.12.1
# pyomo                                    6.10.0
# PyOpenGL                                 3.1.10
# pyOpenSSL                                24.2.1
# pyparsing                                3.3.2
# pyperclip                                1.11.0
# pyproj                                   3.7.2
# pyroaring                                1.0.3
# pysal                                    25.7
# pyshp                                    3.0.3
# PySocks                                  1.7.1
# pyspark                                  4.0.2
# pytensor                                 2.38.2
# pytest                                   8.4.2
# python-apt                               0.0.0
# python-box                               7.4.1
# python-dateutil                          2.9.0.post0
# python-dotenv                            1.2.2
# python-fasthtml                          0.12.50
# python-json-logger                       4.0.0
# python-louvain                           0.16
# python-multipart                         0.0.22
# python-slugify                           8.0.4
# python-snappy                            0.7.3
# python-utils                             3.9.1
# pytz                                     2025.2
# pyviz_comms                              3.0.6
# PyWavelets                               1.9.0
# PyYAML                                   6.0.3
# pyzmq                                    26.2.1
# quantecon                                0.11.1
# rasterio                                 1.5.0
# rasterstats                              0.20.0
# ratelim                                  0.1.6
# referencing                              0.37.0
# regex                                    2025.11.3
# requests                                 2.32.4
# requests-oauthlib                        2.0.0
# requests-toolbelt                        1.0.0
# requirements-parser                      0.9.0
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rfc3987-syntax                           1.1.0
# rich                                     13.9.4
# roman-numerals                           4.1.0
# roman-numerals-py                        4.1.0
# rpds-py                                  0.30.0
# rpy2                                     3.5.17
# rsa                                      4.9.1
# rtree                                    1.4.1
# ruff                                     0.15.6
# safehttpx                                0.1.7
# safetensors                              0.7.0
# scikit-image                             0.25.2
# scikit-learn                             1.6.1
# scipy                                    1.16.3
# scooby                                   0.11.0
# scs                                      3.2.11
# seaborn                                  0.13.2
# SecretStorage                            3.5.0
# segregation                              2.5.3
# semantic-version                         2.10.0
# Send2Trash                               2.1.0
# sentence-transformers                    5.3.0
# sentencepiece                            0.2.1
# sentry-sdk                               2.54.0
# setuptools                               75.2.0
# shap                                     0.51.0
# shapely                                  2.1.2
# shellingham                              1.5.4
# simple-parsing                           0.1.8
# simplejson                               3.20.2
# simsimd                                  6.5.16
# six                                      1.17.0
# sklearn-compat                           0.1.5
# sklearn-pandas                           2.2.0
# slicer                                   0.0.8
# smart_open                               7.5.1
# smmap                                    5.0.3
# sniffio                                  1.3.1
# snowballstemmer                          3.0.1
# soundfile                                0.13.1
# soupsieve                                2.8.3
# soxr                                     1.0.0
# spacy                                    3.8.11
# spacy-legacy                             3.0.12
# spacy-loggers                            1.0.5
# spaghetti                                1.7.6
# spanner-graph-notebook                   1.1.8
# spglm                                    1.1.0
# Sphinx                                   8.2.3
# sphinxcontrib-applehelp                  2.0.0
# sphinxcontrib-devhelp                    2.0.0
# sphinxcontrib-htmlhelp                   2.1.0
# sphinxcontrib-jsmath                     1.0.1
# sphinxcontrib-qthelp                     2.0.0
# sphinxcontrib-serializinghtml            2.0.0
# spint                                    1.0.7
# splot                                    1.1.7
# spopt                                    0.7.0
# spreg                                    1.8.5
# SQLAlchemy                               2.0.48
# sqlalchemy-spanner                       1.17.2
# sqlglot                                  25.20.2
# sqlparse                                 0.5.5
# srsly                                    2.5.2
# sse-starlette                            3.3.2
# stanio                                   0.5.1
# starlette                                0.52.1
# statsmodels                              0.14.6
# strictyaml                               1.7.3
# stringzilla                              4.6.0
# stumpy                                   1.13.0
# sympy                                    1.14.0
# tables                                   3.10.2
# tabulate                                 0.9.0
# tbb                                      2022.3.1
# tcmlib                                   1.4.1
# tenacity                                 9.1.4
# tensorboard                              2.19.0
# tensorboard-data-server                  0.7.2
# tensorflow                               2.19.0
# tensorflow-datasets                      4.9.9
# tensorflow_decision_forests              1.12.0
# tensorflow-hub                           0.16.1
# tensorflow-metadata                      1.17.3
# tensorflow-probability                   0.25.0
# tensorflow-text                          2.19.0
# tensorstore                              0.1.82
# termcolor                                3.3.0
# terminado                                0.18.1
# text-unidecode                           1.3
# textblob                                 0.19.0
# tf_keras                                 2.19.0
# tf-slim                                  1.1.0
# thinc                                    8.3.10
# threadpoolctl                            3.6.0
# tifffile                                 2026.3.3
# tiktoken                                 0.12.0
# timm                                     1.0.25
# tinycss2                                 1.4.0
# tobler                                   0.13.0
# tokenizers                               0.22.2
# toml                                     0.10.2
# tomlkit                                  0.13.3
# toolz                                    0.12.1
# torch                                    2.10.0+cpu
# torchao                                  0.10.0
# torchaudio                               2.10.0+cpu
# torchcodec                               0.10.0
# torchdata                                0.11.0
# torchsummary                             1.5.1
# torchtune                                0.6.1
# torchvision                              0.25.0+cpu
# tornado                                  6.5.1
# tqdm                                     4.67.3
# traitlets                                5.7.1
# traittypes                               0.2.3
# transformers                             5.0.0
# treescope                                0.1.10
# tsfresh                                  0.21.1
# tweepy                                   4.16.0
# typeguard                                4.5.1
# typer                                    0.24.1
# typer-slim                               0.24.0
# types-pytz                               2026.1.1.20260304
# types-setuptools                         82.0.0.20260210
# typing_extensions                        4.15.0
# typing-inspection                        0.4.2
# tzdata                                   2025.3
# tzlocal                                  5.3.1
# uc-micro-py                              2.0.0
# umap-learn                               0.5.11
# umf                                      1.0.3
# uri-template                             1.3.0
# uritemplate                              4.2.0
# urllib3                                  2.5.0
# uuid_utils                               0.14.1
# uvicorn                                  0.42.0
# uvloop                                   0.22.1
# vega-datasets                            0.9.0
# wadllib                                  1.3.6
# wandb                                    0.25.1
# wasabi                                   1.1.3
# watchdog                                 6.0.0
# watchfiles                               1.1.1
# wcwidth                                  0.6.0
# weasel                                   0.4.3
# webcolors                                25.10.0
# webencodings                             0.5.1
# websocket-client                         1.9.0
# websockets                               15.0.1
# Werkzeug                                 3.1.6
# wheel                                    0.46.3
# widgetsnbextension                       3.6.10
# wordcloud                                1.9.6
# wrapt                                    2.1.2
# wurlitzer                                3.1.1
# xarray                                   2025.12.0
# xarray-einstats                          0.10.0
# xgboost                                  3.2.0
# xlrd                                     2.0.2
# xxhash                                   3.6.0
# xyzservices                              2025.11.0
# yarl                                     1.23.0
# ydf                                      0.15.0
# yellowbrick                              1.5
# yfinance                                 0.2.66
# zipp                                     3.23.0
# zstandard                                0.25.0

# %% [markdown]
# Si queremos instalar un paquete que no tengamos instalado en Google Colab podemos hacerlo con `!pip intall nombre_paquete`.

# %%
# Ejemplo de instalación de paquete (cowsay)
# !pip install cowsay
# Out:
# Requirement already satisfied: cowsay in /usr/local/lib/python3.12/dist-packages (6.1)

# %%
# Ejemplo de uso de un paquete importado (cowsay)
import cowsay
cowsay.cow("Hola a todos")
# Out:
#   ____________
# | Hola a todos |
#   ============
#             \
#              \
#                ^__^
#                (oo)\_______
#                (__)\       )\/\
#                    ||----w |
#                    ||     ||

# %% [markdown]
# ## 2.2. numpy y matplotlib
#
# **numpy** es un paquete de cálculo numérico y álgebra ampliamente utilizado, que proporciona el tipo *array* (`ndarray`) utilizado en casi todos los proyectos numéricos. Numpy está compilado en C y su velocidad de ejecución es mucho mayor que con Python puro. [Documentación](https://numpy.org).
#
# **matplotlib** es un módulo para generar gráficos 2D y 3D. [Documentación](https://matplotlib.org)
#
# Es común importarlos con los respectivos alias **np** y **plt** (para `matplotlib.pyplot`).

# %%
# importar numpy y matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2.2.1. Numpy *arrays*
#
# En Numpy, el tipo *array* se utiliza para vectores, matrices y matrices multidimensionales.
#
# Los arrays de Numpy se pueden definir directamente a partir de una lista o mediante una función.
#
# #### Arrays unidimensionales
#
# Por defecto todos los elementos que contiene son `float64`, se puede cambiar usando la propiedad dtype pero todos deben ser del mismo tipo.

# %%
# Ejemplo de array creado con una lista
x = np.array([1, 2.5, 5, 10])
print(x,type(x),x.dtype)
# Out:
# [ 1.   2.5  5.  10. ] <class 'numpy.ndarray'> float64

# %% [markdown]
# Funciones para la generación automática de arrays:
# - `zeros(n)`: Array de n ceros
# - `ones(n)`: Array de n unos
# - `arange(n)`: Array simular a la función `range`
# - `empty(n)`: Array de n elementos vacios
# - `linspace(ini,fin,num)`: Array de números espaciados uniformemente
# - `ramdon.rand(n)`: Array de n elementos aleatorios entre 0 y 1
# - etc.

# %%
# Ejemplo de uso de funciones para crear arrays
print(np.zeros(4))
print(np.ones(5))
print(np.arange(3,16,2))
print(np.empty(6))
print(np.linspace(20, 80, 5))
print(np.random.rand(4))
# Out:
# [0. 0. 0. 0.]
# [1. 1. 1. 1. 1.]
# [ 3  5  7  9 11 13 15]
# [0. 0. 2. 0. 4. 0.]
# [20. 35. 50. 65. 80.]
# [0.64001691 0.22314702 0.9825596  0.58368705]

# %% [markdown]
# ## 2.2.2. Gráficas matplotlib
#
# Existen varias formas de crear las gráficas con matplotlib, pero una de las formas más sencillas es usando matplotlib.pyplot (que suele nombrarse como `plt`)
#
# * Inicializar una figura con `plt.figure()`.
# * Trazar algo con ... `plt.plot` (ver la [documentación](https://matplotlib.org) )
# * Fijar etiquetas, títulos, ejes
# * Mostrar la figura con `plt.show()`.

# %%
# Ejemplo de gráfica
x = np.array([1, 2.5, 5, 10])
y = np.random.rand(4)
plt.figure()
plt.plot(x,y, label='y (x)')

plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Figura de ejemplo')
plt.xlim([0, 11])
plt.ylim([0, 1])
plt.grid()
plt.savefig('figura.png') # Se guarda la figura antes de mostrarla
plt.show()

# %% [markdown]
# ### 2.2.3. Matrices
#
# Las matrices son simplemente arrays 2D. Dado que los vectores y las matrices comparten el mismo tipo, la noción de *shape* es muy importante.
#
# El `size` de un array es el número de elementos, mientras que el `shape` indica cómo están dispuestos.

# %%
# Ejemplo de matriz
m = np.array([[0.25, 6.2, 1, 10],[12, 6.2, 6, -5.3]])
print("x, size =",x.size," shape =",x.shape)
print("m, size =",m.size," shape =",m.shape)
# Out:
# x, size = 4  shape = (4,)
# m, size = 8  shape = (2, 4)

# %% [markdown]
# El acceso, asignación, tipo, copia es común y similar al tipo lista.

# %%
# Ejemplo de trabajor con np.array 1D
print(x)
print(x[2],x[-1])
print(x[::-1])

w = np.copy(x)
x[0] = 6.1554
print(x)
print(w)
# Out:
# [ 1.   2.5  5.  10. ]
# 5.0 10.0
# [10.   5.   2.5  1. ]
# [ 6.1554  2.5     5.     10.    ]
# [ 1.   2.5  5.  10. ]

# %%
# Ejemplo de trabajo con np.array 2D
print(m)
print(m[1,2],type(m[1,2]))
print(m[1,:],type(m[1,:]),m[1,:].shape)
print(m[1])
print(m[:,0])
# Out:
# [[ 0.25  6.2   1.   10.  ]
#  [12.    6.2   6.   -5.3 ]]
# 6.0 <class 'numpy.float64'>
# [12.   6.2  6.  -5.3] <class 'numpy.ndarray'> (4,)
# [12.   6.2  6.  -5.3]
# [ 0.25 12.  ]

# %% [markdown]
# ### Filtrado
# podemos poner condiciones para filtrar los arrays, incluyendolas dentro del `[ ]`

# %%
# Ejemplo de filtrado de arrays
print(x[x<7])
# Out:
# [6.1554 2.5    5.    ]

# %% [markdown]
# ### Operaciones con Numpy arrays

# %%
# Ejemplos de operaciones con np.array
v = np.arange(0, 5)
print("v: ", v)
print("2*v: ", 2*v)
print("v + 2.5: ", v + 2.5)
print("v**2 : ", v**2)
print("sqrt(v): ", np.sqrt(v))
# Out:
# v:  [0 1 2 3 4]
# 2*v:  [0 2 4 6 8]
# v + 2.5:  [2.5 3.5 4.5 5.5 6.5]
# v**2 :  [ 0  1  4  9 16]
# sqrt(v):  [0.         1.         1.41421356 1.73205081 2.        ]

# %%
# Ejemplo de gráfica con varias series
square = v**2
root = np.sqrt(v)
plt.figure()
#plt.subplot(1,2,1)
plt.plot(v,v,'b-', label='$y = x$')
plt.plot(v,square,'go--', label='$y = x^2$')

#plt.subplot(1,2,2)
plt.plot(v,root, 'rs-', label='$y = \\sqrt{x}$')
plt.legend()
plt.xlabel('x')
plt.grid()
plt.show()

# %% [markdown]
# ### Algebra lineal con matrices (numpy.linalg)
#
# Numpy viene con un eficiente módulo de álgebra lineal llamado `linalg` (ver la [documentación](https://numpy.org/doc/stable/reference/routines.linalg.html)).
#
# A modo de ejemplo veamos como __resolver ecuaciones e invertir matrices__

# %%
# Ejemplo de resolución de ecuaciones lineales
A = np.array([[3,1], [1,2]])
b = np.array([9,8])
print(A)
print(b)

x_sol = np.linalg.solve(A,b)
print(x_sol)
print (A.dot(x_sol), " == ",b)
# Out:
# [[3 1]
#  [1 2]]
# [9 8]
# [2. 3.]
# [9. 8.]  ==  [9 8]

# %%
# Ejemplo de cálculo de la matriz inversa
A_inv = np.linalg.inv(A)
x_sol2 = A_inv.dot(b)

print(x_sol2)
# Out:
# [2. 3.]

# %% [markdown]
# ## Ejercicio 1:
#
# El siguiente código genera 30 puntos de x e y.
#
# - Usando la función numpy.polyfit realizar una regresión polinomial de orden 3
# - Dibujar la función polinomial junto con los puntos anteriores
# - Calcular el [error cuadrático medio](https://es.wikipedia.org/wiki/Error_cuadr%C3%A1tico_medio) cometido en la aproximación
# - Hacer lo anterior para orden 4, 5 y 6.

# %%
n = 30
x = (np.random.rand(n)-0.5)*6
y = np.sign(x)*np.maximum(np.abs(x)-1.0,0.0)
plt.scatter(x,y)

# %%
# Solución del ejercicio 1

# %% [markdown]
# ## 2.3. Pandas
#
# Pandas es un paquete construido sobre NumPy que proporciona una implementación eficiente de **DataFrames**. Los DataFrames son esencialmente tablas con etiquetas de fila y columna adjuntas, y a menudo con tipos heterogéneos y/o datos perdidos. Además de ofrecer una cómoda interfaz de almacenamiento para datos etiquetados, Pandas implementa una serie de potentes operaciones de datos.
#
# Así como generalmente importamos NumPy bajo el alias ``np``, importaremos Pandas bajo el alias ``pd``.

# %%
import pandas as pd

# %% [markdown]
# ### 2.3.1. Pandas Series
#
#
# Una `Series` Pandas es un array unidimensional de datos indexados (una columna de la tabla)
#
# Se puede acceder al contenido de la misma forma que para los arrays NumPy, con la diferencia de que cuando se selecciona más de un valor, el tipo sigue siendo un Pandas ``Series``.

# %%
# Ejemplo de serie
serie = pd.Series([0.25, 0.5, 0.75, 1.0])
print(serie, type(serie))
print('-----------')
print(serie[0],type(serie[0]))
print('-----------')
print(serie[2:],type(serie[2:]))
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64 <class 'pandas.core.series.Series'>
# -----------
# 0.25 <class 'numpy.float64'>
# -----------
# 2    0.75
# 3    1.00
# dtype: float64 <class 'pandas.core.series.Series'>

# %% [markdown]
# El tipo ``Series`` contiene tanto una secuencia de valores como una secuencia de índices, a los que podemos acceder con los atributos `values` e `index`.
#
# * ``values`` son los valores en forma de array de Numpy
#
# * ``index`` son los índices de la serie

# %%
print(serie.values,type(serie.values))
print('-----------')
print(serie.index,type(serie.index))
# Out:
# [0.25 0.5  0.75 1.  ] <class 'numpy.ndarray'>
# -----------
# RangeIndex(start=0, stop=4, step=1) <class 'pandas.core.indexes.range.RangeIndex'>

# %% [markdown]
# ### Índices de las series
#
# La principal diferencia entre los arrays de NumPy y las Series de Pandas es la presencia de este campo `index`. Por defecto, se establece (como en los arrays de NumPy) como `0,1,...,tamaño_de_la_serie` pero se puede definir explícitamente un índice de Serie diferente. Los índices pueden ser números pero también cadenas. Entonces, el contenido de la serie debe ser accedido usando estos índices definidos.

# %%
# Ejemplo de serie con letras como índices
serie_2 = pd.Series([0.25, 0.5, 0.75, 1.0], index=['a', 'b', 'c', 'd'])
print(serie_2)
print(serie_2['c'])
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64
# 0.75

# %% [markdown]
# ### Series y diccionarios Python
#
# Las series de Pandas y los diccionarios de Python son cercanos semánticamente: mapear claves a valores. Sin embargo, la implementación de series en Pandas suele ser más eficiente que la de diccionarios en el contexto de la ciencia de datos. Naturalmente, las series se pueden construir a partir de diccionarios.

# %%
# Ejemplo de serie creada con un diccionario
poblacion_dic = {'California': 38332521,
                   'Texas': 26448193,
                   'New York': 19651127,
                   'Florida': 19552860,
                   'Illinois': 12882135}
poblacion_ser = pd.Series(poblacion_dic)
print(poblacion_dic)
print('-----------')
print(poblacion_ser)
print('-----------')
print(poblacion_ser['California'])
print('-----------')
print(poblacion_ser['California':'Florida'])
# Out:
# {'California': 38332521, 'Texas': 26448193, 'New York': 19651127, 'Florida': 19552860, 'Illinois': 12882135}
# -----------
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64
# -----------
# 38332521
# -----------
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# dtype: int64

# %% [markdown]
# ### 2.3.2. Pandas DataFrames
#
# DataFrames es el objeto fundamental de Pandas. Los Dataframes se pueden ver como un conjunto de Series con índices comunes, osea una tabla de datos.
#
# Cada `índice` es una línea de la tabla, para la que tenemos varias `columnas`con diferentes nombres.

# %% [markdown]
# #### Creación de Dataframes
#
# Para crear DataFrame se pueden usar las siguientes opciones:
# * Usando Series
# * Usando Matrices de np.array (las columnas e índices se toman: 0,1,2,...)
# * A partir de una *lista* de *diccionarios*. Cuidado, cada elemento de la lista es una fila (correspondiente a los índices 0,1,...) mientras que cada clave del diccionario corresponde a una columna.
# * Desde un *archivo* , típicamente un archivo __csv__ (para valores separados por comas) o de otros tipos (por ejemplo excel)

# %%
# Ejemplo de creación de DataFrame con series
notas = pd.Series( {'Matemáticas': 6.7, 'Termodinámica': 7.8, 'Calor': 5.6, 'Frigorífica': 7.6})
convocatorias = pd.Series( {'Matemáticas': 1, 'Termodinámica': 1, 'Calor': 2, 'Frigorífica': 1})
expediente = pd.DataFrame({"notas": notas, "convocatorias": convocatorias})

print(expediente)
# Out:
#                notas  convocatorias
# Matemáticas      6.7              1
# Termodinámica    7.8              1
# Calor            5.6              2
# Frigorífica      7.6              1

# %% [markdown]
# En los cuadernos Google Colab (o Jupyter), los DataFrames se muestran de una forma más elegante (formato html) cuando se escribe el nombre del dataframe (en lugar de utilizar `print`)

# %%
# Ejemplo de visualización de DataFrame en Jupyter
expediente
# Out:
#                notas  convocatorias
# Matemáticas      6.7              1
# Termodinámica    7.8              1
# Calor            5.6              2
# Frigorífica      7.6              1

# %% [markdown]
# Los DataFrames tienen:
# * index: que son los índices definidos como en Series
# * columns: que son los nombres de las columnas
# * values: que devuelven un array NumPy (2D) con los contenidos

# %%
print(expediente.index)
print(expediente.columns)
print(expediente.values)
# Out:
# Index(['Matemáticas', 'Termodinámica', 'Calor', 'Frigorífica'], dtype='object')
# Index(['notas', 'convocatorias'], dtype='object')
# [[6.7 1. ]
#  [7.8 1. ]
#  [5.6 2. ]
#  [7.6 1. ]]

# %% [markdown]
# *Atención:* Al acceder a un Dataframe, `dataframe_name[nombre_columna]` devuelve la columna correspondiente como Serie.`dataframe_name[indice]` devuelve un error. Veremos más adelante cómo acceder a un índice específico.

# %%
# Ejemplo de acceso a cada serie de DataFrame
print(expediente['notas'])
# print(expediente['Matematicas'])
# Out:
# Matemáticas      6.7
# Termodinámica    7.8
# Calor            5.6
# Frigorífica      7.6
# Name: notas, dtype: float64

# %%
# Ejemplo de creación de DataFrame usando numpy arrays aleatorios
A = np.random.randn(5,3)
dfA = pd.DataFrame(A)
dfA
# Out:
#           0         1         2
# 0  0.025607  0.989313  2.020534
# 1  0.021895 -1.615729  0.498606
# 2  0.803012 -0.594010 -0.149093
# 3  0.445834  2.359244  0.964439
# 4 -0.551324  0.443451  1.184338

# %%
# Cambio de nombres de columnas y de índices
dfA.columns = ['a','b','c']
dfA.index = [0,2,4,6,8]
dfA
# Out:
#           a         b         c
# 0  0.025607  0.989313  2.020534
# 2  0.021895 -1.615729  0.498606
# 4  0.803012 -0.594010 -0.149093
# 6  0.445834  2.359244  0.964439
# 8 -0.551324  0.443451  1.184338

# %%
# Creación de DataFrame usando una lista de diccionarios

diccionario = [{'a': 0, 'b': 0}, {'a': 1, 'b': 2},{'a': 2, 'b': 4}]
df_dic = pd.DataFrame(diccionario)
df_dic
# Out:
#    a  b
# 0  0  0
# 1  1  2
# 2  2  4

# %% [markdown]
# ## Archivo Excel
#
#  Pandas para leer archivos de excel utiliza un paquete llamado _openpyxl_, en Google Colab ya viene instalado.
#
#  Para que el archivo esté accesible a Google Colab debemos subirlo a la "nube" usando el botón de la carpeta del lateral.

# %%
# Ejemplo de lectura de una archivo excel
andalucia = pd.read_excel('Andalucia.xlsx',sheet_name="provincias",index_col="Provincia")
andalucia
# Out:
#            Poblacion   Area  municipios
# Provincia
# Almeria       731792   8774         103
# Cadiz        1245960   7436          45
# Cordoba       776789  13550          77
# Granada       921338  12531         174
# Huelva        525835  10148          80
# Jaen          627190  13489          97
# Malaga       1695651   7308         103
# Sevilla      1947852  14042         106

# %% [markdown]
# Lectura desde un archivo csv con el siguiente formato:
#
#     col_1_nombre,col_2_nombre,col_3_nombre
#     col_1_v1,col_2_v1,col_3_v1
#     col_1_v2,col_2_v2,col_3_v2
#     ...

# %%
# Ejemplo de lectura de archivo csv
meteo = pd.read_csv('sevilla_met.csv')
meteo
# Out:
#       mes  día  hora  T_ext  T_cielo  R_dir  R_dif  hum_abs  hum_rel  \
# 0       1    1     1   15.1      3.7      0      0  0.00792       74
# 1       1    1     2   14.6      3.2      0      0  0.00788       76
# 2       1    1     3   14.1      2.7      0      0  0.00783       78
# 3       1    1     4   13.5      2.1      0      0  0.00772       80
# 4       1    1     5   13.0      1.6      0      0  0.00766       82
# ...   ...  ...   ...    ...      ...    ...    ...      ...      ...
# 8755   12   31    20    9.1     -6.2      0      0  0.00538       75
# 8756   12   31    21    8.3     -7.0      0      0  0.00524       77
# 8757   12   31    22    7.5     -7.8      0      0  0.00515       80
# 8758   12   31    23    6.7     -8.6      0      0  0.00506       83
# 8759   12   31    24    6.0     -9.3      0      0  0.00499       86
#
#       v_viento  d_viento  azi_sol  zen_sol
# 0          1.1       218      0.0     90.0
# 1          0.7       207      0.0     90.0
# 2          0.6       249      0.0     90.0
# 3          0.8       265      0.0     90.0
# 4          0.8       263      0.0     90.0
# ...        ...       ...      ...      ...
# 8755       1.4       174      0.0     90.0
# 8756       1.0        69      0.0     90.0
# 8757       0.1       210      0.0     90.0
# 8758       0.1       163      0.0     90.0
# 8759       0.1       178      0.0     90.0
#
# [8760 rows x 13 columns]

# %%
# Para ver las primeras líneas usamos la función head(n)
meteo.head(12)
# Out:
#     mes  día  hora  T_ext  T_cielo  R_dir  R_dif  hum_abs  hum_rel  v_viento  \
# 0     1    1     1   15.1      3.7      0      0  0.00792       74       1.1
# 1     1    1     2   14.6      3.2      0      0  0.00788       76       0.7
# 2     1    1     3   14.1      2.7      0      0  0.00783       78       0.6
# 3     1    1     4   13.5      2.1      0      0  0.00772       80       0.8
# 4     1    1     5   13.0      1.6      0      0  0.00766       82       0.8
# 5     1    1     6   12.5      1.1      0      0  0.00768       85       1.1
# 6     1    1     7   12.0      0.6      0      0  0.00761       87       0.8
# 7     1    1     8   12.3      0.9      0     12  0.00767       86       1.7
# 8     1    1     9   13.5      2.1     46     63  0.00782       81       1.2
# 9     1    1    10   15.2      3.8    148    107  0.00797       74       3.2
# 10    1    1    11   16.5      5.2    189    140  0.00820       70       2.3
# 11    1    1    12   18.1      6.8    296    182  0.00830       64       2.3
#
#     d_viento  azi_sol  zen_sol
# 0        218      0.0     90.0
# 1        207      0.0     90.0
# 2        249      0.0     90.0
# 3        265      0.0     90.0
# 4        263      0.0     90.0
# 5        252      0.0     90.0
# 6        231      0.0     90.0
# 7        237    -58.1     89.3
# 8        214    -47.5     80.2
# 9        253    -35.6     72.6
# 10        50    -22.3     67.1
# 11       226     -7.4     64.1

# %% [markdown]
# ### Accediendo a DataFrames
#
# Obteniendo subconjuntos de nuestro DataFrame
# Para acceder a filas completas Pandas incluye las siguientes funciones:
#
# * iloc: Usando los índices por defecto, como si fuera numpy
# * loc: Usado índices propios.

# %%
# Ejemplo de acceso a columnas, elementos, filas
print(meteo['T_ext'])
print(meteo['T_ext'][4])
print(meteo.iloc[4])
# Out:
# 0       15.1
# 1       14.6
# 2       14.1
# 3       13.5
# 4       13.0
#         ...
# 8755     9.1
# 8756     8.3
# 8757     7.5
# 8758     6.7
# 8759     6.0
# Name: T_ext, Length: 8760, dtype: float64
# 13.0
# mes           1.00000
# día           1.00000
# hora          5.00000
# T_ext        13.00000
# T_cielo       1.60000
# R_dir         0.00000
# R_dif         0.00000
# hum_abs       0.00766
# hum_rel      82.00000
# v_viento      0.80000
# d_viento    263.00000
# azi_sol       0.00000
# zen_sol      90.00000
# Name: 4, dtype: float64

# %%
# Ejemplo de acceso a las 12 primeras filas
meteo.iloc[:12]
# Out:
#     mes  día  hora  T_ext  T_cielo  R_dir  R_dif  hum_abs  hum_rel  v_viento  \
# 0     1    1     1   15.1      3.7      0      0  0.00792       74       1.1
# 1     1    1     2   14.6      3.2      0      0  0.00788       76       0.7
# 2     1    1     3   14.1      2.7      0      0  0.00783       78       0.6
# 3     1    1     4   13.5      2.1      0      0  0.00772       80       0.8
# 4     1    1     5   13.0      1.6      0      0  0.00766       82       0.8
# 5     1    1     6   12.5      1.1      0      0  0.00768       85       1.1
# 6     1    1     7   12.0      0.6      0      0  0.00761       87       0.8
# 7     1    1     8   12.3      0.9      0     12  0.00767       86       1.7
# 8     1    1     9   13.5      2.1     46     63  0.00782       81       1.2
# 9     1    1    10   15.2      3.8    148    107  0.00797       74       3.2
# 10    1    1    11   16.5      5.2    189    140  0.00820       70       2.3
# 11    1    1    12   18.1      6.8    296    182  0.00830       64       2.3
#
#     d_viento  azi_sol  zen_sol
# 0        218      0.0     90.0
# 1        207      0.0     90.0
# 2        249      0.0     90.0
# 3        265      0.0     90.0
# 4        263      0.0     90.0
# 5        252      0.0     90.0
# 6        231      0.0     90.0
# 7        237    -58.1     89.3
# 8        214    -47.5     80.2
# 9        253    -35.6     72.6
# 10        50    -22.3     67.1
# 11       226     -7.4     64.1

# %%
# acceso algunas columnas de las 12 primeras filas
meteo.loc[:12,"mes":"T_ext"]
# Out:
#     mes  día  hora  T_ext
# 0     1    1     1   15.1
# 1     1    1     2   14.6
# 2     1    1     3   14.1
# 3     1    1     4   13.5
# 4     1    1     5   13.0
# 5     1    1     6   12.5
# 6     1    1     7   12.0
# 7     1    1     8   12.3
# 8     1    1     9   13.5
# 9     1    1    10   15.2
# 10    1    1    11   16.5
# 11    1    1    12   18.1
# 12    1    1    13   18.5

# %% [markdown]
# ### Operaciones con DataFrames
#
# Podemos aplicar operaciones/funciones tipo Numpy a los DataFrames

# %%
# DataFrame A
dfA
# Out:
#           a         b         c
# 0  0.025607  0.989313  2.020534
# 2  0.021895 -1.615729  0.498606
# 4  0.803012 -0.594010 -0.149093
# 6  0.445834  2.359244  0.964439
# 8 -0.551324  0.443451  1.184338

# %%
# Ejemplo de operación con DataFrame
dfB = np.cos(dfA * np.pi/2 ) - 1
dfB
# Out:
#           a         b         c
# 0 -0.000809 -0.983213 -1.999480
# 2 -0.000591 -1.823291 -0.291347
# 4 -0.695486 -0.404628 -0.027299
# 6 -0.235360 -1.844964 -0.944170
# 8 -0.352135 -0.232953 -1.285529

# %%
# Ejemplo de suma
dfA+dfB
# Out:
#           a         b         c
# 0  0.024799  0.006099  0.021054
# 2  0.021303 -3.439020  0.207259
# 4  0.107526 -0.998638 -0.176392
# 6  0.210474  0.514280  0.020269
# 8 -0.903459  0.210498 -0.101190

# %% [markdown]
# Operaciones con columnass:

# %%
# Crear una nueva columna operando con columnas
andalucia["densidad"] = andalucia["Poblacion"]/andalucia["Area"]
andalucia
# Out:
#            Poblacion   Area  municipios    densidad
# Provincia
# Almeria       731792   8774         103   83.404605
# Cadiz        1245960   7436          45  167.557827
# Cordoba       776789  13550          77   57.327601
# Granada       921338  12531         174   73.524699
# Huelva        525835  10148          80   51.816614
# Jaen          627190  13489          97   46.496404
# Malaga       1695651   7308         103  232.026683
# Sevilla      1947852  14042         106  138.716137

# %%
# Otro ejemplo de operaciones con coulmnas
meteo["alt_sol"] = 90-meteo["zen_sol"]
meteo.head(12)
# Out:
#     mes  día  hora  T_ext  T_cielo  R_dir  R_dif  hum_abs  hum_rel  v_viento  \
# 0     1    1     1   15.1      3.7      0      0  0.00792       74       1.1
# 1     1    1     2   14.6      3.2      0      0  0.00788       76       0.7
# 2     1    1     3   14.1      2.7      0      0  0.00783       78       0.6
# 3     1    1     4   13.5      2.1      0      0  0.00772       80       0.8
# 4     1    1     5   13.0      1.6      0      0  0.00766       82       0.8
# 5     1    1     6   12.5      1.1      0      0  0.00768       85       1.1
# 6     1    1     7   12.0      0.6      0      0  0.00761       87       0.8
# 7     1    1     8   12.3      0.9      0     12  0.00767       86       1.7
# 8     1    1     9   13.5      2.1     46     63  0.00782       81       1.2
# 9     1    1    10   15.2      3.8    148    107  0.00797       74       3.2
# 10    1    1    11   16.5      5.2    189    140  0.00820       70       2.3
# 11    1    1    12   18.1      6.8    296    182  0.00830       64       2.3
#
#     d_viento  azi_sol  zen_sol  alt_sol
# 0        218      0.0     90.0      0.0
# 1        207      0.0     90.0      0.0
# 2        249      0.0     90.0      0.0
# 3        265      0.0     90.0      0.0
# 4        263      0.0     90.0      0.0
# 5        252      0.0     90.0      0.0
# 6        231      0.0     90.0      0.0
# 7        237    -58.1     89.3      0.7
# 8        214    -47.5     80.2      9.8
# 9        253    -35.6     72.6     17.4
# 10        50    -22.3     67.1     22.9
# 11       226     -7.4     64.1     25.9

# %% [markdown]
# La función apply permite aplicarle cualquier función a una columna

# %%
# Ejemplo de uso de la función apply
def grados_dia_cal(T_ext, T = 20):
    if (T_ext < T):
       return (T - T_ext)
    else:
        return 0

gd = meteo["T_ext"].apply(grados_dia_cal,args=[20])
gd.sum()
# Out:
# np.float64(38814.0)

# %% [markdown]
# ###  Estadísticas básicas
#
# La función `describe`dá los valores estadísticos básicos

# %%
meteo.describe()
# Out:
#                mes          día         hora        T_ext      T_cielo  \
# count  8760.000000  8760.000000  8760.000000  8760.000000  8760.000000
# mean      6.526027    15.720548    12.500000    17.604463     5.364749
# std       3.448048     8.796749     6.922582     7.297511     7.727115
# min       1.000000     1.000000     1.000000     0.200000   -14.200000
# 25%       4.000000     8.000000     6.750000    11.900000    -0.400000
# 50%       7.000000    16.000000    12.500000    16.800000     4.800000
# 75%      10.000000    23.000000    18.250000    22.700000    10.825000
# max      12.000000    31.000000    24.000000    38.500000    27.500000
#
#              R_dir        R_dif      hum_abs      hum_rel     v_viento  \
# count  8760.000000  8760.000000  8760.000000  8760.000000  8760.000000
# mean    132.074886    64.503311     0.007189    58.320205     2.850034
# std     215.235640    86.008646     0.002008    16.167016     2.261565
# min       0.000000     0.000000     0.003150    19.000000     0.000000
# 25%       0.000000     0.000000     0.005610    46.000000     1.100000
# 50%       0.000000     0.000000     0.006840    59.000000     2.300000
# 75%     205.000000   111.250000     0.008600    71.000000     4.000000
# max    1053.000000   419.000000     0.013460   100.000000    16.000000
#
#           d_viento       azi_sol      zen_sol      alt_sol
# count  8760.000000  8.760000e+03  8760.000000  8760.000000
# mean    195.277283 -1.946692e-17    74.626210    15.373790
# std     108.293179  4.552221e+01    20.340964    20.340964
# min       0.000000 -1.124000e+02    18.400000     0.000000
# 25%      93.000000 -7.400000e+00    61.600000     0.000000
# 50%     218.000000  0.000000e+00    89.600000     0.400000
# 75%     279.000000  7.400000e+00    90.000000    28.400000
# max     360.000000  1.124000e+02    90.000000    71.600000

# %%
# Cada una de las series pueden aplicarse multiples funciones muy similares a las np.array
meteo["T_ext"].max()
# Out:
# 38.5

# %% [markdown]
# ### Agrupaciones
#
# para agrupar podemos usar la función groupby()

# %%
meteo.groupby("mes")["T_ext"].mean()
# Out:
# mes
# 1     10.780914
# 2     11.712946
# 3     13.125806
# 4     14.896944
# 5     18.203226
# 6     22.316250
# 7     26.288710
# 8     26.088710
# 9     23.165139
# 10    18.893414
# 11    13.971528
# 12    11.366667
# Name: T_ext, dtype: float64

# %% [markdown]
# ### Filtrado
#
# Filtrado es la selección de valores que cumplan determinadas condiciones

# %%
# Ejemplo de Filtrado al estilo np.array
meteo[meteo["T_ext"] > 35]
# Out:
#       mes  día  hora  T_ext  T_cielo  R_dir  R_dif  hum_abs  hum_rel  \
# 4548    7    9    13   35.5     21.2    752    187  0.01051       29
# 4549    7    9    14   36.2     21.7    739    163  0.01016       27
# 4550    7    9    15   36.5     24.4    542    201  0.00994       26
# 4551    7    9    16   36.4     21.8    487    145  0.00989       26
# 4552    7    9    17   35.6     21.2    326    106  0.01020       28
# ...   ...  ...   ...    ...      ...    ...    ...      ...      ...
# 5678    8   25    15   35.2     20.5    567    128  0.00925       26
# 5679    8   25    16   35.3     20.6    455    119  0.00930       26
# 5821    8   31    14   35.4     20.7    716    114  0.00935       26
# 5822    8   31    15   35.7     20.9    561    118  0.00914       25
# 5823    8   31    16   35.6     20.8    463     71  0.00909       25
#
#       v_viento  d_viento  azi_sol  zen_sol  alt_sol
# 4548       5.0       248     21.2     19.4     70.6
# 4549       6.0       283     52.5     26.4     63.6
# 4550       6.0       293     71.2     36.4     53.6
# 4551       6.9       249     83.6     47.5     42.5
# 4552       7.5       216     93.5     58.9     31.1
# ...        ...       ...      ...      ...      ...
# 5678       0.8       356     58.3     44.5     45.5
# 5679       0.8        21     72.2     54.8     35.2
# 5821       9.8       304     38.1     37.7     52.3
# 5822       8.5       155     56.4     46.1     43.9
# 5823       8.1       182     70.3     56.3     33.7
#
# [71 rows x 14 columns]

# %%
# Ejemplo de filtrado con la funcion query
meteo.query('T_ext > 35 and hum_rel < 25')
# Out:
#       mes  día  hora  T_ext  T_cielo  R_dir  R_dif  hum_abs  hum_rel  \
# 4766    7   18    15   35.6     20.6    736    108  0.00872       24
# 4789    7   19    14   35.2     20.2    776    141  0.00853       24
# 4790    7   19    15   35.6     20.5    710    131  0.00835       23
# 4791    7   19    16   35.4     20.2    485    138  0.00826       23
# 5076    7   31    13   36.1     21.2    771    166  0.00896       24
# 5077    7   31    14   36.8     21.9    763    128  0.00893       23
# 5078    7   31    15   37.0     21.9    640    129  0.00863       22
# 5079    7   31    16   36.9     21.8    543    106  0.00858       22
# 5080    7   31    17   36.1     21.0    300    107  0.00859       23
#
#       v_viento  d_viento  azi_sol  zen_sol  alt_sol
# 4766       6.3       188     69.4     37.3     52.7
# 4789       1.9       238     50.4     27.5     62.5
# 4790       2.1       217     69.3     37.4     52.6
# 4791       1.6       210     82.2     48.4     41.6
# 5076       6.0       306     18.2     23.3     66.7
# 5077       6.0       300     47.3     29.6     60.4
# 5078       7.5       288     66.2     39.1     50.9
# 5079       6.9       291     79.3     50.0     40.0
# 5080       5.6       316     90.1     61.3     28.7

# %% [markdown]
# ### Usando Matplolib con pandas
#
# Matplotlib se integra perfectamente con Pandas

# %%
# Ejemplo de creación de una fila con la fecha con pd.date_range
time = pd.date_range(start ='01-01-2001', periods = 8760, freq ='1h')
meteo['time'] = time
meteo
# Out:
#       mes  día  hora  T_ext  T_cielo  R_dir  R_dif  hum_abs  hum_rel  \
# 0       1    1     1   15.1      3.7      0      0  0.00792       74
# 1       1    1     2   14.6      3.2      0      0  0.00788       76
# 2       1    1     3   14.1      2.7      0      0  0.00783       78
# 3       1    1     4   13.5      2.1      0      0  0.00772       80
# 4       1    1     5   13.0      1.6      0      0  0.00766       82
# ...   ...  ...   ...    ...      ...    ...    ...      ...      ...
# 8755   12   31    20    9.1     -6.2      0      0  0.00538       75
# 8756   12   31    21    8.3     -7.0      0      0  0.00524       77
# 8757   12   31    22    7.5     -7.8      0      0  0.00515       80
# 8758   12   31    23    6.7     -8.6      0      0  0.00506       83
# 8759   12   31    24    6.0     -9.3      0      0  0.00499       86
#
#       v_viento  d_viento  azi_sol  zen_sol  alt_sol                time
# 0          1.1       218      0.0     90.0      0.0 2001-01-01 00:00:00
# 1          0.7       207      0.0     90.0      0.0 2001-01-01 01:00:00
# 2          0.6       249      0.0     90.0      0.0 2001-01-01 02:00:00
# 3          0.8       265      0.0     90.0      0.0 2001-01-01 03:00:00
# 4          0.8       263      0.0     90.0      0.0 2001-01-01 04:00:00
# ...        ...       ...      ...      ...      ...                 ...
# 8755       1.4       174      0.0     90.0      0.0 2001-12-31 19:00:00
# 8756       1.0        69      0.0     90.0      0.0 2001-12-31 20:00:00
# 8757       0.1       210      0.0     90.0      0.0 2001-12-31 21:00:00
# 8758       0.1       163      0.0     90.0      0.0 2001-12-31 22:00:00
# 8759       0.1       178      0.0     90.0      0.0 2001-12-31 23:00:00
#
# [8760 rows x 15 columns]

# %%
# Ejemplo de uso de la función plot de los DataFrame
meteo.plot(x="time",y="T_ext")
# Out:
# <Axes: xlabel='time'>

# %%
# Ejemplo de uso de plt con series de Pandas
plt.figure()
plt.plot(meteo["time"],meteo["hum_rel"],"r-")
plt.show()

# %%
# Ejemplo de histogramas
plt.figure()
plt.hist(meteo["T_ext"],100)
plt.show()

# %%
# Ejemplo de curva de frecuencia acumulada
plt.figure()
plt.hist(meteo["T_ext"],100,histtype="step",density=True,cumulative=True)
plt.show()

# %% [markdown]
# ### Uso del paquete plotly
#
# plotly es un paquete que crea gráficas dinámicas a las que podemos hacer zoom, y otras acciones.

# %%
# Ejemplo de uso de plotly
import plotly.express as px

fig = px.line(meteo,x='time',y=['T_ext'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="77369a5e-1928-4ff6-8e2d-d73b27ee715e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77369a5e-1928-4ff6-8e2d-d73b27ee715e")) {                    Plotly.newPlot(                        "77369a5e-1928-4ff6-8e2d-d73b27ee715e",                        [{"hovertemplate":"variable=T_ext\u003cbr\u003etime=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"T_ext","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"T_ext","showlegend":true,"x":["2001-01-01T00:00:00","2001-01-01T01:00:00","2001-01-01T02:00:00","2001-01-01T03:00:00","2001-01-01T04:00:00","2001-01-01T05:00:00","2001-01-01T06:00:00","2001-01-01T07:00:00","2001-01-01T08:00:00","2001-01-01T09:00:00","2001-01-01T10:00:00","2001-01-01T11:00:00","2001-01-01T12:00:00","2001-01-01T13:00:00","2001-01-01T14:00:00","2001-01-01T15:00:00","2001-01-01T16:00:00","2001-01-01T17:00:00","2001-01-01T18:00:00","2001-01-01T19:00:00","2001-01-01T20:00:00","2001-01-01T21:00:00","2001-01-01T22:00:00","2001-01-01T23:00:00","2001-01-02T00:00:00","2001-01-02T01:00:00","2001-01-02T02:00:00","2001-01-02T03:00:00","2001-01-02T04:00:00","2001-01-02T05:00:00","2001-01-02T06:00:00","2001-01-02T07:00:00","2001-01-02T08:00:00","2001-01-02T09:00:00","2001-01-02T10:00:00","2001-01-02T11:00:00","2001-01-02T12:00:00","2001-01-02T13:00:00","2001-01-02T14:00:00","2001-01-02T15:00:00","2001-01-02T16:00:00","2001-01-02T17:00:00","2001-01-02T18:00:00","2001-01-02T19:00:00","2001-01-02T20:00:00","2001-01-02T21:00:00","2001-01-02T22:00:00","2001-01-02T23:00:00","2001-01-03T00:00:00","2001-01-03T01:00:00","2001-01-03T02:00:00","2001-01-03T03:00:00","2001-01-03T04:00:00","2001-01-03T05:00:00","2001-01-03T06:00:00","2001-01-03T07:00:00","2001-01-03T08:00:00","2001-01-03T09:00:00","2001-01-03T10:00:00","2001-01-03T11:00:00","2001-01-03T12:00:00","2001-01-03T13:00:00","2001-01-03T14:00:00","2001-01-03T15:00:00","2001-01-03T16:00:00","2001-01-03T17:00:00","2001-01-03T18:00:00","2001-01-03T19:00:00","2001-01-03T20:00:00","2001-01-03T21:00:00","2001-01-03T22:00:00","2001-01-03T23:00:00","2001-01-04T00:00:00","2001-01-04T01:00:00","2001-01-04T02:00:00","2001-01-04T03:00:00","2001-01-04T04:00:00","2001-01-04T05:00:00","2001-01-04T06:00:00","2001-01-04T07:00:00","2001-01-04T08:00:00","2001-01-04T09:00:00","2001-01-04T10:00:00","2001-01-04T11:00:00","2001-01-04T12:00:00","2001-01-04T13:00:00","2001-01-04T14:00:00","2001-01-04T15:00:00","2001-01-04T16:00:00","2001-01-04T17:00:00","2001-01-04T18:00:00","2001-01-04T19:00:00","2001-01-04T20:00:00","2001-01-04T21:00:00","2001-01-04T22:00:00","2001-01-04T23:00:00","2001-01-05T00:00:00","2001-01-05T01:00:00","2001-01-05T02:00:00","2001-01-05T03:00:00","2001-01-05T04:00:00","2001-01-05T05:00:00","2001-01-05T06:00:00","2001-01-05T07:00:00","2001-01-05T08:00:00","2001-01-05T09:00:00","2001-01-05T10:00:00","2001-01-05T11:00:00","2001-01-05T12:00:00","2001-01-05T13:00:00","2001-01-05T14:00:00","2001-01-05T15:00:00","2001-01-05T16:00:00","2001-01-05T17:00:00","2001-01-05T18:00:00","2001-01-05T19:00:00","2001-01-05T20:00:00","2001-01-05T21:00:00","2001-01-05T22:00:00","2001-01-05T23:00:00","2001-01-06T00:00:00","2001-01-06T01:00:00","2001-01-06T02:00:00","2001-01-06T03:00:00","2001-01-06T04:00:00","2001-01-06T05:00:00","2001-01-06T06:00:00","2001-01-06T07:00:00","2001-01-06T08:00:00","2001-01-06T09:00:00","2001-01-06T10:00:00","2001-01-06T11:00:00","2001-01-06T12:00:00","2001-01-06T13:00:00","2001-01-06T14:00:00","2001-01-06T15:00:00","2001-01-06T16:00:00","2001-01-06T17:00:00","2001-01-06T18:00:00","2001-01-06T19:00:00","2001-01-06T20:00:00","2001-01-06T21:00:00","2001-01-06T22:00:00","2001-01-06T23:00:00"," ...

# %% [markdown]
# ## Ejercicio 2:
#
# El fichero titanic.csv contiene información sobre los pasajeros del Titanic. Escribir un programa con los siguientes requisitos:
#
# 1. Generar un DataFrame con los datos del fichero usando como índice la primera columna (PassengerId).
# 2. Mostrar por pantalla las dimensiones del DataFrame, el número de datos que contiene, los nombres de sus columnas y filas, los tipos de datos de las columnas, las 10 primeras filas y las 10 últimas filas.
# 3. Mostrar por pantalla los datos del pasajero con identificador 148.
# 4. Mostrar por pantalla los nombres de las personas que iban en primera clase ordenadas alfabéticamente.
# 5. Mostrar por pantalla el porcentaje de personas que sobrevivieron y murieron.
# 5. Mostrar por pantalla el porcentaje de personas que sobrevivieron en cada clase.
# 6. Eliminar del DataFrame los pasajeros con edad desconocida.
# 7. Mostrar por pantalla la edad media de las mujeres que viajaban en cada clase.
# 8.  Añadir una nueva columna booleana para ver si el pasajero era menor de edad o no.
# 9.  Mostrar por pantalla el porcentaje de menores y mayores de edad que sobrevivieron en cada clase.
# 10.  Dibujar un gráfico de frecuencia acumulada con la edad de los pasajeros.

# %%
# Solución:
